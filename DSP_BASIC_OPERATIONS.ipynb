# %% [markdown]
# <a href="https://colab.research.google.com/github/mruganknetke12-cloud/exp1/blob/main/DSP_BASIC_OPERATIONS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello")
# Out:
# Hello

# %%
name = input("Enter your name: ")
print("Hello, ", name)
# Out:
# Enter your name: Mrugank
# Hello,  Mrugank

# %%
X = 5
y = 3.14
z = "hi"
print(X, y, z)
# Out:
# 5 3.14 hi

# %%
X = 10
print(type(X))
x = "Now a string"
print(type(x))
# Out:
# <class 'int'>
# <class 'str'>

# %%
a = b = c = 100
print(a, b, c)
x, y, z= 1, 2.5, "Python"
print(x, y, z)
# Out:
# 100 100 100
# 1 2.5 Python

# %%
X = 10
del x
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3668/2230128031.py in <cell line: 0>()
#       1 X = 10
# ----> 2 del x
#       3 print(x)
#
# NameError: name 'x' is not defined

# %%
a = 15
b = 4
print("Addition: ", a + b)
print("Subtraction: ", a - b)
print("Multiplication:", a * b)
print("Division: ", a / b)
print("Floor Division: ", a // b)
print("Modulus:", a % b)
print("Exponentiation:", a ** b)

# %%
a = 13
b = 33
print(a > b)
print(a < b)
print(a == b)
print(a == b)
print(a >= b)
print(a <= b)

# %%
a = True
b = False
print(a and b)
print(a or b)
print(not a)

# %%
a = 10
b = 4
print(a & b)
print(a | b)
print(~a)
print(a ^ b)
print(a >> 2)
print(a << 2)

# %%
a = 10
b = a
print(b)
b += a
print(b)
b = a
print(b)
b = a
print(b)
b **= a
print(b)

# %%
a = 10
b = 20
C = a
print(a is not b)
print(a is c)

# %%
X = 24
y = 20
my_list = [10, 20, 30, 40, 50]

if (X not in my_list):
    print("X is NOT present in given list")
else:
    print("X is present in given list")

if (y in my_list):
    print("y is present in given list")
else:
    print("y is NOT present in given list")

# %%
a, b = 10, 20
min = a if a < b else b
print(min)

# %%
import keyword
print("The list of keywords are: ")
print(keyword.kwlist)

# %%
a = 5
b = 5.0
c = 2 + 4j
print(type(a))
print(type(b))
print(type(c))

# %%
s = 'Welcome to the Geeks World'
print(s)
print(type(s))
# access string with index
print(s[0])
print(s[-1])

# %%
a = [1, 2, 3]
print(a)
b = ["Geeks", "For", "Geeks", 4, 5]
print(b[0])
print(b[-3])

# %%
t1 = (1,)
print(type(t1))
t2 = ('Geeks', 'For', 'Geeks', 1, 2)
print(t2[3])
print(t2[-3])

# %%
print(type(True))
print(type (False))

# %%
s1 = {"a","a", "b", "c", "b"}
print(s1)
s2 = ("Geeks", "For", "Geeks")
for i in s2:
    print(i)

# %%
d = {1: 'Geeks', 2: 'For', 3: 'Geeks'}
print(d[1])
print(d.get(2))
